# %%
import pandas as pd
StuPerfDF= pd.read_csv('study_performance.csv')
StuPerfDF = StuPerfDF[['gender','lunch','test_preparation_course','math_score','reading_score','writing_score']]
print(StuPerfDF)
# Out:
#      gender         lunch test_preparation_course  math_score  reading_score  \
# 0    female      standard                    none          72             72
# 1    female      standard               completed          69             90
# 2    female      standard                    none          90             95
# 3      male  free/reduced                    none          47             57
# 4      male      standard                    none          76             78
# ..      ...           ...                     ...         ...            ...
# 995  female      standard               completed          88             99
# 996    male  free/reduced                    none          62             55
# 997  female  free/reduced               completed          59             71
# 998  female      standard               completed          68             78
# 999  female  free/reduced                    none          77             86
#
#      writing_score
# 0               74
# ...

# %%
print(StuPerfDF.info())
print(StuPerfDF.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gender                   1000 non-null   object
#  1   lunch                    1000 non-null   object
#  2   test_preparation_course  1000 non-null   object
#  3   math_score               1000 non-null   int64
#  4   reading_score            1000 non-null   int64
#  5   writing_score            1000 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 47.0+ KB
# None
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# ...

# %%
print(StuPerfDF.columns)
# Out:
# Index(['gender', 'lunch', 'test_preparation_course', 'math_score',
#        'reading_score', 'writing_score'],
#       dtype='object')

# %%
print(StuPerfDF['math_score'].mean())
print(StuPerfDF['writing_score'].mean())
print(StuPerfDF['reading_score'].mean())
# Out:
# 66.089
# 68.054
# 69.169

# %%
print(StuPerfDF['math_score'][StuPerfDF['lunch'] == 'standard'].mean())
print(StuPerfDF['math_score'][StuPerfDF['lunch'] != 'standard'].mean())
# Out:
# 70.03410852713178
# 58.92112676056338

# %%
StuPerfDF[['math_score','reading_score','writing_score']][StuPerfDF['test_preparation_course'] == 'none'].mean()
# Out:
# math_score       64.077882
# reading_score    66.534268
# writing_score    64.504673
# dtype: float64

# %%
StuPerfDF[['math_score','reading_score','writing_score']][StuPerfDF['test_preparation_course'] == 'completed'].mean()
# Out:
# math_score       69.695531
# reading_score    73.893855
# writing_score    74.418994
# dtype: float64

# %%
empData = pd.read_csv('employees.csv')
print(empData)
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   70000
# 1      Bob   30   Chicago   80000
# 2  Charlie   28    Boston   75000

# %%
empData[(empData['Age'] < 30) & (empData['Salary'] > 79000)]
# Out:
# Empty DataFrame
# Columns: [Name, Age, City, Salary]
# Index: []

# %%
empData[(empData['Age'] > 30) | (empData['Salary'] > 79000)]
# Out:
#   Name  Age     City  Salary
# 1  Bob   30  Chicago   80000

# %%
empData[(empData['City'] == 'Boston' ) | (empData['Salary'] < 5000 )]
# Out:
#       Name  Age    City  Salary
# 2  Charlie   28  Boston   75000

# %%
empData[(empData['Age'] > 23 ) & (empData['Age'] <= 25 )]
# Out:
#     Name  Age      City  Salary
# 0  Alice   25  New York   70000

# %%
empData[empData['Age'].between(23,27)]
# Out:
#     Name  Age      City  Salary
# 0  Alice   25  New York   70000

# %%
empData[empData['Salary'].between(80000,95000)]
# Out:
#   Name  Age     City  Salary
# 1  Bob   30  Chicago   80000

# %%
empData[empData['Name'].str.contains('c',case = False)]
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   70000
# 2  Charlie   28    Boston   75000

# %%
empData[empData['Name'].str.startswith('B')]
# Out:
#   Name  Age     City  Salary
# 1  Bob   30  Chicago   80000

# %%
empData.loc[len(empData)] = ['Abdullah',None,'Muscat',12000]
# Out:
# <ipython-input-81-686d16328d6a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empData.loc[len(empData)] = ['Abdullah',None,'Muscat',12000]

# %%
empData = empData.iloc[:-2]

# %%
empData
# Out:
#        Name   Age      City  Salary
# 0     Alice    25  New York   70000
# 1       Bob    30   Chicago   80000
# 2   Charlie    28    Boston   75000
# 3  Abdullah  None    Muscat   12000

# %%
empData.isnull()
# Out:
#     Name    Age   City  Salary
# 0  False  False  False   False
# 1  False  False  False   False
# 2  False  False  False   False
# 3  False   True  False   False

# %%
empData[empData.isnull().any(axis=1)]
# Out:
#        Name   Age    City  Salary
# 3  Abdullah  None  Muscat   12000

# %%
mask = empData['City'] == 'Muscat'
empData[mask]
# Out:
#        Name   Age    City  Salary
# 3  Abdullah  None  Muscat   12000

# %%
empData['Salary'].mask(empData['Salary'] >  15000,0)
# Out:
# 0        0
# 1        0
# 2        0
# 3    12000
# Name: Salary, dtype: int64

# %%
empData.drop(columns=['Age'])
# Out:
#        Name      City  Salary
# 0     Alice  New York   70000
# 1       Bob   Chicago   80000
# 2   Charlie    Boston   75000
# 3  Abdullah    Muscat   12000

# %%
empData['Bonus'] = empData['Salary']*0.1
# Out:
# <ipython-input-112-9b7226b1221f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empData['Bonus'] = empData['Salary']*0.1

# %%
empData
# Out:
#        Name   Age      City  Salary   Bonus
# 0     Alice    25  New York   70000  7000.0
# 1       Bob    30   Chicago   80000  8000.0
# 2   Charlie    28    Boston   75000  7500.0
# 3  Abdullah  None    Muscat   12000  1200.0

# %%
empData['Age'] = empData['Age'] + 1
# Out:
# <ipython-input-114-a94ff5bd6ab1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empData['Age'] = empData['Age'] + 1

# %%
empData
# Out:
#        Name  Age      City  Salary   Bonus
# 0     Alice   26  New York   70000  7000.0
# 1       Bob   31   Chicago   80000  8000.0
# 2   Charlie   29    Boston   75000  7500.0
# 3  Abdullah  NaN    Muscat   12000  1200.0

# %%
empData.rename(columns={'Salary':'Income'})
# Out:
#        Name  Age      City  Income   Bonus
# 0     Alice   26  New York   70000  7000.0
# 1       Bob   31   Chicago   80000  8000.0
# 2   Charlie   29    Boston   75000  7500.0
# 3  Abdullah  NaN    Muscat   12000  1200.0

# %%
empData.drop('Bonus',axis=1)
# Out:
#        Name  Age      City  Salary
# 0     Alice   26  New York   70000
# 1       Bob   31   Chicago   80000
# 2   Charlie   29    Boston   75000
# 3  Abdullah  NaN    Muscat   12000

# %%
empData
# Out:
#        Name  Age      City  Salary   Bonus
# 0     Alice   26  New York   70000  7000.0
# 1       Bob   31   Chicago   80000  8000.0
# 2   Charlie   29    Boston   75000  7500.0
# 3  Abdullah  NaN    Muscat   12000  1200.0

# %%
empData.fillna(0)
# Out:
# <ipython-input-124-c2a14f9ed569>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   empData.fillna(0)
#        Name  Age      City  Salary   Bonus
# 0     Alice   26  New York   70000  7000.0
# 1       Bob   31   Chicago   80000  8000.0
# 2   Charlie   29    Boston   75000  7500.0
# 3  Abdullah    0    Muscat   12000  1200.0

# %%
empData_clean = empData.fillna(0)
empData_clean
# Out:
# <ipython-input-127-850c5e72c48d>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   empData_clean = empData.fillna(0)
#        Name  Age      City  Salary   Bonus
# 0     Alice   26  New York   70000  7000.0
# 1       Bob   31   Chicago   80000  8000.0
# 2   Charlie   29    Boston   75000  7500.0
# 3  Abdullah    0    Muscat   12000  1200.0

# %%
empData_clean.sort_values('Name')
# Out:
#        Name  Age      City  Salary   Bonus
# 3  Abdullah    0    Muscat   12000  1200.0
# 0     Alice   26  New York   70000  7000.0
# 1       Bob   31   Chicago   80000  8000.0
# 2   Charlie   29    Boston   75000  7500.0

# %%
empData_clean.sort_values('Salary',ascending=False)
# Out:
#        Name  Age      City  Salary   Bonus
# 1       Bob   31   Chicago   80000  8000.0
# 2   Charlie   29    Boston   75000  7500.0
# 0     Alice   26  New York   70000  7000.0
# 3  Abdullah    0    Muscat   12000  1200.0

# %%
empData.groupby('City')['Salary'].mean()
# Out:
# City
# Boston      75000.0
# Chicago     80000.0
# Muscat      12000.0
# New York    70000.0
# Name: Salary, dtype: float64

# %%
empData.groupby('City')['Salary'].max()
# Out:
# City
# Boston      75000
# Chicago     80000
# Muscat      12000
# New York    70000
# Name: Salary, dtype: int64

# %%
empData['City'].value_counts()
# Out:
# City
# New York    1
# Chicago     1
# Boston      1
# Muscat      1
# Name: count, dtype: int64

# %%
empData.to_csv('Indexed_updated_Employees.csv',index=True)
